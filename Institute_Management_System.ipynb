# %%
from getpass import getpass

coaching = {"a_user":["MarkX","Aashu"],
            "a_pass":["markx0254j","amitmishra18"],
            "s_user":["UDAY","KRISHNA","KUSUM","JAYA","SAKSHI"],
            "s_pass":["uday@123","krishna@123","kusum@123","jaya@123","sakshi@123"],
            "s_id":[25400,25401,25402,25403,25404],
            "course":{"English":[],
                      "Hindi":[],
                      "Maths":[],
                      "Science":[],
                      "Sst":[]},
            "block":[],
            "block1":[]}

print("*"*77)
print("-"*77)
print("WELCOME TO MAHARAJA COACHING CLASSES".center(77))
print("-"*77)
print("*"*77)



while True:
    print(f"""\n1. Admin Login.\n2. Student Login.\n3. Explore Courses.\n4. Contect Us.\n5. Exit""")
    ch = input("\nEnter your choice --->  ")
    
    if ch == "1":
        a_name = input("\nEnter Admin username (case senctive) -> ").strip()
        count = 1
        if a_name in coaching["a_user"]:
            
            if a_name not in coaching["block1"]:
                index = coaching["a_user"].index(a_name)
                
                while count<=3:
                    print("\nEnter your password :- ")
                    a_pass = getpass()
                    
                    if a_pass == coaching["a_pass"][index]:
                        print(f"\nWelcome {a_name} into Admin Panel.")
                        while True:
                            print("\n1. Manage Students.\n2. Manage Courses\n3. Logout")
                            a_op = input("\nEnter your choice -> ")

                            if a_op == "1":
                                """__________________________________________________________________________________________________________"""
                                while True:
                                    print("\n1. Add student.\n2. Remove student.\n3. Register for course\n4. Remove Student from course.\n5. Show all Students.\n6. Back to Menu.")
                                    m_op = input("\nEnter your choice.")

                                    if m_op == "1":
                                        m_s = input("Enter the name of student -> ").upper()
                                        if m_s not in coaching["s_user"]:
                                            coaching["s_user"].append(m_s)
                                            m_p = input("Create password -> ")
                                            coaching["s_pass"].append(m_p)
                                            coaching["s_id"].append(coaching["s_id"][-1]+1)
                                            print("\nStudent added successfully.")
                                        else:
                                            print("\nStudent already in list.")
                                            continue
                                            """-------------------------------------------------------------------"""
                                    elif m_op == "2":
                                        m_s = input("Enter the name of student -> ").upper()
                                        if m_s not in coaching["s_user"]:
                                            print("\nStudent not found in list.")
                                            continue
                                        else:
                                            coaching["s_pass"].pop((coaching["s_user"].index(m_s)))
                                            coaching["s_id"].pop((coaching["s_user"].index(m_s)))
                                            coaching["s_user"].remove(m_s)
                                            print("\nStudent removed successfully.")
                                            continue

                                            """-------------------------------------------------------------------"""
                                    elif m_op == "3":
                                        m_s = input("Enter the name of student -> ").upper()
                                        if m_s in coaching["s_user"]:
                                            m_c = input("Enter course name -> ").title()
                                            if m_c in coaching["course"]:
                                                if m_s in coaching["course"][m_c]:
                                                    print("\nStudent is present in the list already.")
                                                    continue
                                                else:
                                                    coaching["course"][m_c].append(m_s)
                                                    print("\nRegistration has been successfully done.")
                                                    continue
                                            else:
                                                print("\nCourse not found.")
                                                continue
                                        else:
                                            print("\nStudent not found.")
                                            continue
                                            """--------------------------------------------------------------------"""
                                    elif m_op == "4":

                                        m_s = input("Enter the name of student -> ").upper()
                                        if m_s in coaching["s_user"]:
                                            m_c = input("Enter course name -> ").title()
                                            if m_c in coaching["course"]:
                                                coaching["course"][m_c].remove(m_s)
                                                print("\nStudent removed from course has been successfully done.")
                                                continue
                                            else:
                                                print("\nCourse not found in list.")
                                                continue
                                        else:
                                            print("\nStudent doesn't exist.")
                                            """---------------------------------------------------------------------"""

                                    elif m_op == "5":
                                        count = 0
                                        print("\nAll Students -> ")
                                        for var in coaching["s_user"]:
                                            print(var)
                                            count+=1
                                        if count==0:
                                            print("\n0")

                                            """---------------------------------------------------------------------"""

                                    elif m_op == "6":
                                        break
                                    else:
                                        print("\nEnter a valid choice.")
                #____________________________________________________________________________________________________________________"""
                            elif a_op == "2":
                                while True:
                                    print("\n1. Add Course\n2. Remove Course\n3. Show all courses.\n4. Back to Menu.")
                                    c_ch = input("\nEnter your choice -> ")

                                    if c_ch == "1":
                                        new_c = input("\nEnter course name which u want to add -> ").title()
                                        if new_c in coaching["course"]:
                                            print("\nThe course is already present.")
                                            continue
                                        else:
                                            coaching["course"].setdefault(new_c,[])
                                            print("\nThe course is added successfully.")
                                            continue
                                            """----------------------------------------------------------------------------"""

                                    elif c_ch == "2":
                                        rm_c = input("\nEnter course name which u want to remove -> ").title().strip()

                                        if rm_c in coaching["course"]:
                                            print("\nIf you delete the course then the course data will also be destroy.")
                                            rm_op = input("\n Are you sure want to delete the course :- (y/n)")
                                            if rm_op.lower().strip() == "yes" or rm_op.lower().strip() == "y":
                                                coaching["course"].pop(rm_c)

                                                #for key in coaching["course"]

                                                print("\nThe course has been successfully deleted.")

                                                continue
                                            else:
                                                print("\nThe course has been not deleted.")
                                                continue
                                        else:
                                            print("\nCourse not found.")
                                            continue

                                            """----------------------------------------------------------------------------"""
                                    elif c_ch == "3":
                                        count = 0
                                        print("\nAll courses :- ")
                                        for var in coaching["course"]:
                                            print(var,end = "")
                                            print(",",end = " ")
                                            count+=1
                                        if count==0:
                                            print("\n0")

                                        """---------------------------------------------------------------------------------"""
                                    elif c_ch == "4":
                                        break
                                    else:
                                        print("\nEnter a valid choice.")
                                    continue

                #________________________________________________________________________________________________________________________"""
                            elif a_op == "3":
                                a_con = input("\nDo you really want to exit (y/n)??   ")
                                if a_con.lower().strip() == "yes" or a_con.lower().strip() == "y":
                                    print("\nYou have been Successfully Loged out.")
                                    break
                                else:
                                    continue
                            else:
                                print("\nEnter a valid choice.")
                        break
                    elif count<3:
                        print(f"\nIncorrect Password.\nPlease try again.\nYou have only {3-(count)} attempts to login.")
                        count+=1
                        continue
                    else:
                        coaching["block1"].append(a_name)
                        print("\nYour all attempts is used and you cant login again before 24 Hours.")
                        break
            else:
                print("The user is Blocked.\nPlease try again after some time.")
            continue
        else:
            print("\nUsername doesn't exist.")
                #__________________________________________________________________________________________________________________________________________""" 

    elif ch == "2":
        s_name = input("\nEnter Student's name -> ").upper().strip()
        count = 1
        if s_name in coaching["s_user"]:
            
            if s_name not in coaching["block"]:
                index = coaching["s_user"].index(s_name)
                
                while count<=3:
                    print("\nEnter your password :- ")
                    s_pass = getpass()
                    
                    if s_pass == coaching["s_pass"][index]:
                        a = coaching["s_id"][index]
                        print(f"\nWelcome {s_name} in Maharaja Coaching Classes.")
                        
                        while True:
                            print("\n1. Change Username.\n2. Change Password.\n3. Show Details.\n4. Logout.")
                            s_op = input("\nEnter your choice -> ").strip()
                            
                            if s_op == "1":
                                new_su = input("\nEnter new username -> ").upper().strip()
                                
                                if new_su == coaching["s_user"][index]:
                                    print("\nNew Username must be different from old username.")
                                    continue
                                else:
                                    coaching["s_user"][index] = new_su
                                    print("\nYour username has been changed successfully.")
                                    continue
                            elif s_op == "2":
                                cur_sp = getpass("\nEnter your current password -> ")
                                if cur_sp == coaching["s_pass"][index]:
                                    new_sp = input("\nEnter your new password -> ")
                                    coaching["s_pass"][index] = new_sp
                                    print("\nYour password has been changed successfully.")
                                    continue
                                else:
                                    print("\nPassword is incorrect.")
                                    continue
                            elif s_op == "3":
                                a = coaching["s_user"][index]
                                b = coaching["s_id"][index]
                                c = coaching["s_pass"][index]
                                print(f"\nName = {a}\nID = {b}\nPassword = {c}")
                                count = 0
                                print(f"\nCourses in which {s_name } is enrolled -> ")
                                for key in coaching["course"]:
                                    if s_name in coaching["course"][key]:
                                        print(key,end = "")
                                        print(",",end = " ")
                                        count+=1
                                if count == 0:
                                    print(0)
                                continue
                            elif s_op == "4":
                                print("\nYou have been successfully Loged out.")
                                break
                            else:
                                print("\nEnter a valid choice.")
                        break
                        
                    elif count<3:
                        print(f"\nIncorrect Password.\nPlease try again.\nYou have only {3-(count)} attempts to login.")
                        count+=1
                        continue
                    else:
                        coaching["block"].append(s_name)
                        print("\nYour all attempts is used and you cant login again before 24 Hours.")
                        break
            else:
                print("The user is Blocked.\nPlease try again after some time.")
            continue
        else:
            print("\nUsername doesn't exist.")
            
            
    elif ch == "3":
        print("\nAll Courses :- ",*list(coaching["course"].keys()),sep = ", ")
        continue
    
#_______________________________________________________________________________________________________________________________________"""
    
    elif ch == "4":
        print("""\nAddress   -> \nHOUSE NO. 10, BAPU NAGAR, BLOCK A, \nMALKA GANJ LANDMARK NEAR MALKA GANJ\nPOST OFFICE, DELHI North Delhi DL 110007""")
        print("\nContect No. -> \n8278635332\n1800998822")
        print("\nEmail add . -> \nmaharajacoaching@classes.org")
        continue
        
#________________________________________________________________________________________________________________________"""
    
    
    elif ch == "5":
        con = input("\nDo you really want to exit (y/n)??   ")
        if con.lower().strip() == "yes" or con.lower().strip() == "y":
            print("\nThanks for viewing our website!")
            break
        else:
            continue
    else:
        print("\nEnter a valid choice.")
# Out:
# *****************************************************************************
# -----------------------------------------------------------------------------
#                      WELCOME TO MAHARAJA COACHING CLASSES
# -----------------------------------------------------------------------------
# *****************************************************************************
#
# 1. Admin Login.
# 2. Student Login.
# 3. Explore Courses.
# 4. Contect Us.
# 5. Exit
#
# Enter your choice --->  1
#
# Enter Admin username (case senctive) -> MarkX
#
# Enter your password :-
# ········
#
# Welcome MarkX into Admin Panel.
#
# 1. Manage Students.
# 2. Manage Courses
# 3. Logout
#
# Enter your choice -> 3
#
# Do you really want to exit (y/n)??   y
#
# You have been Successfully Loged out.
#
# 1. Admin Login.
# 2. Student Login.
# 3. Explore Courses.
# 4. Contect Us.
# 5. Exit
#
# Enter your choice --->  1
#
# Enter Admin username (case senctive) -> jsdflkaf
#
# Username doesn't exist.
#
# ...
